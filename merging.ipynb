# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### Install necessary libraries

# %%
# !pip install requests bs4 pandas lxml geocoder
# Out:
# Requirement already satisfied: requests in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (2.24.0)
# Requirement already satisfied: bs4 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (0.0.1)
# Requirement already satisfied: pandas in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (1.2.0)
# Requirement already satisfied: lxml in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (4.6.2)
# Requirement already satisfied: geocoder in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (1.38.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from pandas) (1.19.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from pandas) (2020.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: future in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: click in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: ratelim in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: six in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from beautifulsoup4->bs4) (2.1)
# Requirement already satisfied: decorator in c:\users\acs\scoop\apps\miniconda3\4.9.2\lib\site-packages (from ratelim->geocoder) (4.4.2)

# %% [markdown]
# ### Import necessary libraries

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import geocoder

# %% [markdown]
# Get a request for the target table, and get it into dataframe format

# %%
req = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(req.content, "lxml")
table = soup.find_all("table")[0]
df = pd.read_html(str(table))[0]
df
# Out:
#     Postal Code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# ..          ...               ...
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Filter all the rows where the borough is "Not assigned"

# %%
df_f = df.loc[~df.Borough.str.contains("Not assigned") ]
df_f.reset_index(drop=True, inplace=True)
df_f
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business reply mail Processing Centre, South C...
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 102  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# ### Verify if the postal codes are unique

# %%
postal_codes = df_f["Postal Code"].unique()
print(f"There are {len(postal_codes)} unique postal codes for {len(df_f)} rows.")
if len(postal_codes) == len(df_f):
    print("There are no duplicate postal codes.")
# Out:
# There are 103 unique postal codes for 103 rows.
# There are no duplicate postal codes.

# %%
df_f.loc[df_f["Postal Code"].str.contains(postal_codes[3])]
# Out:
#   Postal Code     Borough                     Neighbourhood
# 3         M6A  North York  Lawrence Manor, Lawrence Heights

# %%
print(len(df_f), len(postal_codes))
# Out:
# 103 103

# %% [markdown]
# ### Check for unassigned Burroughs

# %%
df_f.loc[df_f["Neighbourhood"].str.contains("Not assigned")]
# Out:
# Empty DataFrame
# Columns: [Postal Code, Borough, Neighbourhood]
# Index: []

# %% [markdown]
# ### Try to get data from geocoder

# %%
postal_dict = {}

for postal_code in postal_codes:

    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.google(f'{postal_code}, Toronto, Ontario')
        lat_lng_coords = g.latlng
        print(".")
    print(postal_code, lat_lng_coords)
    postal_dict[postal_code] = lat_lng_coords

postal_dict
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-5c681d2d5a63> in <module>
#       8     # loop until you get the coordinates
#       9     while(lat_lng_coords is None):
# ---> 10         g = geocoder.google(f'{postal_code}, Toronto, Ontario')
#      11         lat_lng_coords = g.latlng
#      12         print(".")
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\base.py in _connect(self)
#     477         try:
#     478             # make request and get response
# --> 479             self.response = response = self.rate_limited_get(
#     480                 self.url,
#     481                 params=self.params,
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# <decorator-gen-120> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\ratelim\__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# <decorator-gen-119> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\ratelim\__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\google.py in rate_limited_get_for_dev(self, *args, **kwargs)
#     272     @ratelim.greedy(10, 1)
#     273     def rate_limited_get_for_dev(self, *args, **kwargs):
# --> 274         return super(GoogleQuery, self).rate_limited_get(*args, **kwargs)
#     275
#     276     @ratelim.greedy(100000, 60 * 60 * 24)  # Google for Work daily limit
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\geocoder\base.py in rate_limited_get(self, url, **kwargs)
#     508     def rate_limited_get(self, url, **kwargs):
#     509         """ By default, simply wraps a session.get request"""
# --> 510         return self.session.get(url, **kwargs)
#     511
#     512     def _adapt_results(self, json_response):
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\urllib3\connection.py in connect(self)
#     360             context.load_default_certs()
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#     364             keyfile=self.key_file,
#
# ~\scoop\apps\miniconda3\current\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data)
#     384     ) or IS_SECURETRANSPORT:
#     385         if HAS_SNI and server_hostname is not None:
# --> 386             return context.wrap_socket(sock, server_hostname=server_hostname)
#     387
#     388         warnings.warn(
#
# ~\scoop\apps\miniconda3\current\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~\scoop\apps\miniconda3\current\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~\scoop\apps\miniconda3\current\lib\ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
g
# Out:
# <[REQUEST_DENIED] Google - Geocode [empty]>

# %% [markdown]
# Didn't work, better try the csv file

# %%
new_df = pd.read_csv("Geospatial_Coordinates.csv")
new_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
lats = []
longs = []

for idx,postal_code in df_f["Postal Code"].iteritems():
    row2 = new_df.loc[new_df["Postal Code"]==postal_code]
    lats.append(row2.Latitude.values[0])
    longs.append(row2.Longitude.values[0])

df_f["Latitude"] = lats
df_f["Longitude"] = longs
df_f.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#        Latitude      Longitude
# 0  [43.7532586]  [-79.3296565]
# 1  [43.7258823]  [-79.3155716]
# 2  [43.6542599]  [-79.3606359]
# 3   [43.718518]  [-79.4647633]
# 4  [43.6623015]  [-79.3894938]
